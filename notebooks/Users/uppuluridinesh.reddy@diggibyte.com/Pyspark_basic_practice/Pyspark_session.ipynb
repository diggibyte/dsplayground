>3.92</td><td>4063500</td></tr><tr><td>2010-08-10</td><td>3.93</td><td>3.93</td><td>3.764</td><td>3.806</td><td>3.806</td><td>6406500</td></tr><tr><td>2010-08-11</td><td>3.738</td><td>3.776</td><td>3.57</td><td>3.58</td><td>3.58</td><td>3988000</td></tr><tr><td>2010-08-12</td><td>3.56</td><td>3.58</td><td>3.478</td><td>3.52</td><td>3.52</td><td>3455000</td></tr><tr><td>2010-08-13</td><td>3.636</td><td>3.69</td><td>3.532</td><td>3.664</td><td>3.664</td><td>3170000</td></tr><tr><td>2010-08-16</td><td>3.69</td><td>3.76</td><td>3.652</td><td>3.756</td><td>3.756</t ...

# %%
# checking the data types
data.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: [(&#39;Date&#39;, &#39;string&#39;),
#  (&#39;Open&#39;, &#39;string&#39;),
#  (&#39;High&#39;, &#39;string&#39;),
#  (&#39;Low&#39;, &#39;string&#39;),
#  (&#39;Close&#39;, &#39;string&#39;),
#  (&#39;Adj Close&#39;, &#39;string&#39;),
#  (&#39;Volume&#39;, &#39;string&#39;)]</div>

# %%
# getting the first 3 rows of data from spark dataframe
data.head(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[8]: [Row(Date=&#39;2010-06-29&#39;, Open=&#39;3.8&#39;, High=&#39;5.0&#39;, Low=&#39;3.508&#39;, Close=&#39;4.778&#39;, Adj Close=&#39;4.778&#39;, Volume=&#39;93831500&#39;),
#  Row(Date=&#39;2010-06-30&#39;, Open=&#39;5.158&#39;, High=&#39;6.084&#39;, Low=&#39;4.66&#39;, Close=&#39;4.766&#39;, Adj Close=&#39;4.766&#39;, Volume=&#39;85935500&#39;),
#  Row(Date=&#39;2010-07-01&#39;, Open=&#39;5.0&#39;, High=&#39;5.184&#39;, Low=&#39;4.054&#39;, Close=&#39;4.392&#39;, Adj Close=&#39;4.392&#39;, Volume=&#39;41094000&#39;)]</div>

# %%
data.show(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+-----+-----+-----+-----+---------+--------+
#       Date| Open| High|  Low|Close|Adj Close|  Volume|
# +----------+-----+-----+-----+-----+---------+--------+
# 2010-06-29|  3.8|  5.0|3.508|4.778|    4.778|93831500|
# 2010-06-30|5.158|6.084| 4.66|4.766|    4.766|85935500|
# +----------+-----+-----+-----+-----+---------+--------+
# only showing top 2 rows
#
# </div>

# %%
data.first()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[15]: Row(Date=&#39;2010-06-29&#39;, Open=&#39;3.8&#39;, High=&#39;5.0&#39;, Low=&#39;3.508&#39;, Close=&#39;4.778&#39;, Adj Close=&#39;4.778&#39;, Volume=&#39;93831500&#39;)</div>

# %%
data.describe().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+----------+------------------+------------------+------------------+------------------+------------------+--------------------+
# summary|      Date|              Open|              High|               Low|             Close|         Adj Close|              Volume|
# +-------+----------+------------------+------------------+------------------+------------------+------------------+--------------------+
#   count|      2959|              2959|              2959|              2959|              2959|              2959|                2959|
#    mean|      null|139.61124442176418|142.71524748834068|136.33782908178446|139.70102506928023|139.70102506928023| 3.131279073774924E7|
#  stddev|      null|251.58282914270785|257.44632055674396|245.32811392573947|251.73080643686905|251.73080643686905|2.7970409778982457E7|
#     min|2010-06-29|              10.1|             10.04|              10.1|            10.038|            10.038|           100283000|
#     max|2022-03-28|        996.340027|        997.859985|        997.559998|        999.109985|        999.109985|            99483500|
# +-------+----------+------------------+------------------+------------------+------------------+------------------+--------------------+
#
# </div>

# %%
data.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[12]: [&#39;Date&#39;, &#39;Open&#39;, &#39;High&#39;, &#39;Low&#39;, &#39;Close&#39;, &#39;Adj Close&#39;, &#39;Volume&#39;]</div>

# %%
data.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[13]: 2959</div>

# %% [markdown]
# ### Creating a new column as stock_Date with the reference of Date column

# %%
data = data.withColumn('stock_Date', data.Date)

data.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+-----+-----+-----+-----+---------+--------+----------+
#       Date| Open| High|  Low|Close|Adj Close|  Volume|stock_Date|
# +----------+-----+-----+-----+-----+---------+--------+----------+
# 2010-06-29|  3.8|  5.0|3.508|4.778|    4.778|93831500|2010-06-29|
# 2010-06-30|5.158|6.084| 4.66|4.766|    4.766|85935500|2010-06-30|
# 2010-07-01|  5.0|5.184|4.054|4.392|    4.392|41094000|2010-07-01|
# 2010-07-02|  4.6| 4.62|3.742| 3.84|     3.84|25699000|2010-07-02|
# 2010-07-06|  4.0|  4.0|3.166|3.222|    3.222|34334500|2010-07-06|
# +----------+-----+-----+-----+-----+---------+--------+----------+
# only showing top 5 rows
#
# </div>

# %% [markdown]
# ### Renaming the column

# %%
data = data.withColumnRenamed('stock_Date', 'Stock_date')

data.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+-----+-----+-----+-----+---------+--------+----------+
#       Date| Open| High|  Low|Close|Adj Close|  Volume|Stock_date|
# +----------+-----+-----+-----+-----+---------+--------+----------+
# 2010-06-29|  3.8|  5.0|3.508|4.778|    4.778|93831500|2010-06-29|
# 2010-06-30|5.158|6.084| 4.66|4.766|    4.766|85935500|2010-06-30|
# 2010-07-01|  5.0|5.184|4.054|4.392|    4.392|41094000|2010-07-01|
# 2010-07-02|  4.6| 4.62|3.742| 3.84|     3.84|25699000|2010-07-02|
# 2010-07-06|  4.0|  4.0|3.166|3.222|    3.222|34334500|2010-07-06|
# +----------+-----+-----+-----+-----+---------+--------+----------+
# only showing top 5 rows
#
# </div>

# %% [markdown]
# ### Dropping the extra created colun from the spark dataframe

# %%
# after dropping the added column we are having the existing columns
data = data.drop('Stock_date')

data.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+-----+-----+-----+-----+---------+--------+
#       Date| Open| High|  Low|Close|Adj Close|  Volume|
# +----------+-----+-----+-----+-----+---------+--------+
# 2010-06-29|  3.8|  5.0|3.508|4.778|    4.778|93831500|
# 2010-06-30|5.158|6.084| 4.66|4.766|    4.766|85935500|
# 2010-07-01|  5.0|5.184|4.054|4.392|    4.392|41094000|
# 2010-07-02|  4.6| 4.62|3.742| 3.84|     3.84|25699000|
# 2010-07-06|  4.0|  4.0|3.166|3.222|    3.222|34334500|
# +----------+-----+-----+-----+-----+---------+--------+
# only showing top 5 rows
#
# </div>

# %% [markdown]
# ### Imputting the missing values

# %%
# Remove Rows with Missing Values

data.na.drop()
data.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+-----+-----+-----+-----+---------+--------+
#       Date| Open| High|  Low|Close|Adj Close|  Volume|
# +----------+-----+-----+-----+-----+---------+--------+
# 2010-06-29|  3.8|  5.0|3.508|4.778|    4.778|93831500|
# 2010-06-30|5.158|6.084| 4.66|4.766|    4.766|85935500|
# 2010-07-01|  5.0|5.184|4.054|4.392|    4.392|41094000|
# 2010-07-02|  4.6| 4.62|3.742| 3.84|     3.84|25699000|
# 2010-07-06|  4.0|  4.0|3.166|3.222|    3.222|34334500|
# +----------+-----+-----+-----+-----+---------+--------+
# only showing top 5 rows
#
# </div>

# %% [markdown]
# ### Selecting the single column and multiple column

# %%
## Selecting Single Column

data.select('High').show(5)

## Selecting Multiple columns

data.select(['Open', 'High', 'Low']).show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+
#  High|
# +-----+
#   5.0|
# 6.084|
# 5.184|
#  4.62|
#   4.0|
# +-----+
# only showing top 5 rows
#
# +-----+-----+-----+
#  Open| High|  Low|
# +-----+-----+-----+
#   3.8|  5.0|3.508|
# 5.158|6.084| 4.66|
#   5.0|5.184|4.054|
#   4.6| 4.62|3.742|
#   4.0|  4.0|3.166|
# +-----+-----+-----+
# only showing top 5 rows
#
# </div>

# %% [markdown]
# ### filtering the column

# %%
from pyspark.sql.functions import col, lit

data.filter((col('Open') >= lit('2010-07-01')) | (col('Open') <= lit('2010-07-31'))).show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+-----+-----+-----+-----+---------+--------+
#       Date| Open| High|  Low|Close|Adj Close|  Volume|
# +----------+-----+-----+-----+-----+---------+--------+
# 2010-06-29|  3.8|  5.0|3.508|4.778|    4.778|93831500|
# 2010-06-30|5.158|6.084| 4.66|4.766|    4.766|85935500|
# 2010-07-01|  5.0|5.184|4.054|4.392|    4.392|41094000|
# 2010-07-02|  4.6| 4.62|3.742| 3.84|     3.84|25699000|
# 2010-07-06|  4.0|  4.0|3.166|3.222|    3.222|34334500|
# +----------+-----+-----+-----+-----+---------+--------+
# only showing top 5 rows
#
# </div>

# %% [markdown]
# ### filtering the data by using the between condition

# %%
## fetch the data where the adjusted value is between 100.0 and 500.0

data.filter(data.High.between(4.0, 4.5)).show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+-----+----+-----+-----+---------+--------+
#       Date| Open|High|  Low|Close|Adj Close|  Volume|
# +----------+-----+----+-----+-----+---------+--------+
# 2010-07-06|  4.0| 4.0|3.166|3.222|    3.222|34334500|
# 2010-07-14|3.588|4.03|3.552|3.968|    3.968|20976000|
# 2010-07-15|3.988| 4.3|  3.8|3.978|    3.978|18699000|
# 2010-07-16| 4.14|4.26| 4.01|4.128|    4.128|13106500|
# 2010-07-19|4.274|4.45|4.184|4.382|    4.382|12432500|
# +----------+-----+----+-----+-----+---------+--------+
# only showing top 5 rows
#
# </div>

# %% [markdown]
# ### filtering the data by using the When condition

# %%
from pyspark.sql import functions as f
data.select('open', 'close', 
            f.when(data.High >= 4.0, 1).otherwise(0)
           ).show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+-----+-----------------------------------------+
#  open|close|CASE WHEN (High &gt;= 4.0) THEN 1 ELSE 0 END|
# +-----+-----+-----------------------------------------+
#   3.8|4.778|                                        1|
# 5.158|4.766|                                        1|
#   5.0|4.392|                                        1|
#   4.6| 3.84|                                        1|
#   4.0|3.222|                                        1|
# +-----+-----+-----------------------------------------+
# only showing top 5 rows
#
# </div>

# %% [markdown]
# ### filtering the data by using the like condition

# %%
data.select('Open', 
            data.Open.rlike('^[3]').alias('open with 3')
            ).distinct().show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+-----------+
#  Open|open with 3|
# +-----+-----------+
#   3.8|       true|
# 5.158|      false|
#   5.0|      false|
#  3.28|       true|
#   4.6|      false|
# +-----+-----------+
# only showing top 5 rows
#
# </div>
