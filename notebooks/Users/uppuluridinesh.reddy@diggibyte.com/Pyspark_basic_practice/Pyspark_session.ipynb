# %% [markdown]
# ### Creating Pyspark Session

# %%
import pyspark
from pyspark.sql import SparkSession

# creating a spark session
spark = SparkSession.builder.appName("pyspark practice").getOrCreate()

display(spark)
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=8687747474966386#setting/sparkui/0313-190753-gzhmricf/driver-8597104253192353991">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*, 4]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ### Creating a Spark dataframe

# %%
Spark_data = [
    ("James",None,"M"),
    ("Anna","NY","F"),
    ("Julia",None,None)
]

columns = ["name","state","gender"]
df =spark.createDataFrame(Spark_data,columns)
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>state</th><th>gender</th></tr></thead><tbody><tr><td>James</td><td>null</td><td>M</td></tr><tr><td>Anna</td><td>NY</td><td>F</td></tr><tr><td>Julia</td><td>null</td><td>null</td></tr></tbody></table></div>

# %%
# %fs
ls /mnt/tf-abfss/data/ds/food_inspection_dinesh
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/tf-abfss/data/ds/food_inspection_dinesh/Food_Inspections.csv</td><td>Food_Inspections.csv</td><td>250745613</td></tr><tr><td>dbfs:/mnt/tf-abfss/data/ds/food_inspection_dinesh/tesla_stocks.csv</td><td>tesla_stocks.csv</td><td>186958</td></tr></tbody></table></div>

# %% [markdown]
# ### Reading a csv file

# %%
csv_file = '/mnt/tf-abfss/data/ds/food_inspection_dinesh/tesla_stocks.csv'
df = spark.read.csv(csv_file)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# displaying the dataframe without header is true
display(df.head(3))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>_c1</th><th>_c2</th><th>_c3</th><th>_c4</th><th>_c5</th><th>_c6</th></tr></thead><tbody><tr><td>Date</td><td>Open</td><td>High</td><td>Low</td><td>Close</td><td>Adj Close</td><td>Volume</td></tr><tr><td>2010-06-29</td><td>3.8</td><td>5.0</td><td>3.508</td><td>4.778</td><td>4.778</td><td>93831500</td></tr><tr><td>2010-06-30</td><td>5.158</td><td>6.084</td><td>4.66</td><td>4.766</td><td>4.766</td><td>85935500</td></tr></tbody></table></div>

# %% [markdown]
# ### Creating a dataframe with header is true

# %%
# printing the schema of the data
data = spark.read.csv(
    '/mnt/tf-abfss/data/ds/food_inspection_dinesh/tesla_stocks.csv',inferSchema=True,
    sep = ',',
    header = True,
    )

data.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- Date: string (nullable = true)
# -- Open: double (nullable = true)
# -- High: double (nullable = true)
# -- Low: double (nullable = true)
# -- Close: double (nullable = true)
# -- Adj Close: double (nullable = true)
# -- Volume: integer (nullable = true)
#
# </div>

# %%
display(data.show(3))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+-----+-----+-----+-----+---------+--------+
#       Date| Open| High|  Low|Close|Adj Close|  Volume|
# +----------+-----+-----+-----+-----+---------+--------+
# 2010-06-29|  3.8|  5.0|3.508|4.778|    4.778|93831500|
# 2010-06-30|5.158|6.084| 4.66|4.766|    4.766|85935500|
# 2010-07-01|  5.0|5.184|4.054|4.392|    4.392|41094000|
# +----------+-----+-----+-----+-----+---------+--------+
# only showing top 3 rows
#
# </div>

# %%
# checking the data types
data.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[8]: [(&#39;Date&#39;, &#39;string&#39;),
#  (&#39;Open&#39;, &#39;double&#39;),
#  (&#39;High&#39;, &#39;double&#39;),
#  (&#39;Low&#39;, &#39;double&#39;),
#  (&#39;Close&#39;, &#39;double&#39;),
#  (&#39;Adj Close&#39;, &#39;double&#39;),
#  (&#39;Volume&#39;, &#39;int&#39;)]</div>

# %%
# getting the first 2 rows of data from spark dataframe
data.head(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: [Row(Date=&#39;2010-06-29&#39;, Open=3.8, High=5.0, Low=3.508, Close=4.778, Adj Close=4.778, Volume=93831500),
#  Row(Date=&#39;2010-06-30&#39;, Open=5.158, High=6.084, Low=4.66, Close=4.766, Adj Close=4.766, Volume=85935500)]</div>

# %%
data.show(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+-----+-----+-----+-----+---------+--------+
#       Date| Open| High|  Low|Close|Adj Close|  Volume|
# +----------+-----+-----+-----+-----+---------+--------+
# 2010-06-29|  3.8|  5.0|3.508|4.778|    4.778|93831500|
# 2010-06-30|5.158|6.084| 4.66|4.766|    4.766|85935500|
# +----------+-----+-----+-----+-----+---------+--------+
# only showing top 2 rows
#
# </div>

# %%
data.first()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[11]: Row(Date=&#39;2010-06-29&#39;, Open=3.8, High=5.0, Low=3.508, Close=4.778, Adj Close=4.778, Volume=93831500)</div>

# %%
data.describe().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+----------+------------------+------------------+------------------+------------------+------------------+--------------------+
# summary|      Date|              Open|              High|               Low|             Close|         Adj Close|              Volume|
# +-------+----------+------------------+------------------+------------------+------------------+------------------+--------------------+
#   count|      2959|              2959|              2959|              2959|              2959|              2959|                2959|
#    mean|      null|139.61124442176418|142.71524748834068|136.33782908178446|139.70102506928023|139.70102506928023| 3.131279073774924E7|
#  stddev|      null|251.58282914270785|257.44632055674396|245.32811392573947|251.73080643686905|251.73080643686905|2.7970409778982457E7|
#     min|2010-06-29|             3.228|             3.326|             2.996|              3.16|              3.16|              592500|
#     max|2022-03-28|       1234.410034|        1243.48999|            1217.0|       1229.910034|       1229.910034|           304694000|
# +-------+----------+------------------+------------------+------------------+------------------+------------------+--------------------+
#
# </div>

# %%
data.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[13]: [&#39;Date&#39;, &#39;Open&#39;, &#39;High&#39;, &#39;Low&#39;, &#39;Close&#39;, &#39;Adj Close&#39;, &#39;Volume&#39;]</div>

# %%
data.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[14]: 2959</div>

# %% [markdown]
# ### Creating a new column as stock_Date with the reference of Date column

# %%
data = data.withColumn('stock_Date', data.Date)

data.show(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+-----+-----+-----+-----+---------+--------+----------+
#       Date| Open| High|  Low|Close|Adj Close|  Volume|stock_Date|
# +----------+-----+-----+-----+-----+---------+--------+----------+
# 2010-06-29|  3.8|  5.0|3.508|4.778|    4.778|93831500|2010-06-29|
# 2010-06-30|5.158|6.084| 4.66|4.766|    4.766|85935500|2010-06-30|
# +----------+-----+-----+-----+-----+---------+--------+----------+
# only showing top 2 rows
#
# </div>

# %% [markdown]
# ### Renaming the column

# %%
data = data.withColumnRenamed('stock_Date', 'Stock_date')

data.show(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+-----+-----+-----+-----+---------+--------+----------+
#       Date| Open| High|  Low|Close|Adj Close|  Volume|Stock_date|
# +----------+-----+-----+-----+-----+---------+--------+----------+
# 2010-06-29|  3.8|  5.0|3.508|4.778|    4.778|93831500|2010-06-29|
# 2010-06-30|5.158|6.084| 4.66|4.766|    4.766|85935500|2010-06-30|
# +----------+-----+-----+-----+-----+---------+--------+----------+
# only showing top 2 rows
#
# </div>

# %% [markdown]
# ### Dropping the extra created colun from the spark dataframe

# %%
# after dropping the added column we are having the existing columns
data = data.drop('Stock_date')

data.show(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+-----+-----+-----+-----+---------+--------+
#       Date| Open| High|  Low|Close|Adj Close|  Volume|
# +----------+-----+-----+-----+-----+---------+--------+
# 2010-06-29|  3.8|  5.0|3.508|4.778|    4.778|93831500|
# 2010-06-30|5.158|6.084| 4.66|4.766|    4.766|85935500|
# 2010-07-01|  5.0|5.184|4.054|4.392|    4.392|41094000|
# +----------+-----+-----+-----+-----+---------+--------+
# only showing top 3 rows
#
# </div>

# %%
### any==how
data.na.drop(how="any").show(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+-----+-----+-----+-----+---------+--------+
#       Date| Open| High|  Low|Close|Adj Close|  Volume|
# +----------+-----+-----+-----+-----+---------+--------+
# 2010-06-29|  3.8|  5.0|3.508|4.778|    4.778|93831500|
# 2010-06-30|5.158|6.084| 4.66|4.766|    4.766|85935500|
# +----------+-----+-----+-----+-----+---------+--------+
# only showing top 2 rows
#
# </div>

# %%
##threshold
data.na.drop(how="any",thresh=3).show(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+-----+-----+-----+-----+---------+--------+
#       Date| Open| High|  Low|Close|Adj Close|  Volume|
# +----------+-----+-----+-----+-----+---------+--------+
# 2010-06-29|  3.8|  5.0|3.508|4.778|    4.778|93831500|
# 2010-06-30|5.158|6.084| 4.66|4.766|    4.766|85935500|
# +----------+-----+-----+-----+-----+---------+--------+
# only showing top 2 rows
#
# </div>

# %%
from pyspark.sql.functions import col, lit
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### checking the null values

# %%
data.filter(col("Open").isNull()).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+----+----+---+-----+---------+------+
# Date|Open|High|Low|Close|Adj Close|Volume|
# +----+----+----+---+-----+---------+------+
# +----+----+----+---+-----+---------+------+
#
# </div>

# %%
# checking the missing values count using condition of two columns
data.filter(data.Open.isNull() & data.High.isNull()).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[22]: 0</div>

# %% [markdown]
# ### Filter Rows with IS NOT NULL or isNotNull

# %%
data.filter(col("Open").isNotNull()).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[23]: 2959</div>

# %% [markdown]
# ### Imputting the missing values

# %%
# Remove Rows with Missing Values

data.na.drop()
data.show(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+-----+-----+-----+-----+---------+--------+
#       Date| Open| High|  Low|Close|Adj Close|  Volume|
# +----------+-----+-----+-----+-----+---------+--------+
# 2010-06-29|  3.8|  5.0|3.508|4.778|    4.778|93831500|
# 2010-06-30|5.158|6.084| 4.66|4.766|    4.766|85935500|
# 2010-07-01|  5.0|5.184|4.054|4.392|    4.392|41094000|
# +----------+-----+-----+-----+-----+---------+--------+
# only showing top 3 rows
#
# </div>

# %% [markdown]
# ### Selecting the single column and multiple column

# %%
## Selecting Single Column

data.select('High').show(2)

## Selecting Multiple columns

data.select(['Open', 'High', 'Low']).show(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+
#  High|
# +-----+
#   5.0|
# 6.084|
# +-----+
# only showing top 2 rows
#
# +-----+-----+-----+
#  Open| High|  Low|
# +-----+-----+-----+
#   3.8|  5.0|3.508|
# 5.158|6.084| 4.66|
# +-----+-----+-----+
# only showing top 2 rows
#
# </div>

# %% [markdown]
# ### filtering the column

# %%
from pyspark.sql.functions import col, lit

data.filter((col('Open') >= lit('2010-07-01')) | (col('Open') <= lit('2010-07-31'))).show(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+----+----+---+-----+---------+------+
# Date|Open|High|Low|Close|Adj Close|Volume|
# +----+----+----+---+-----+---------+------+
# +----+----+----+---+-----+---------+------+
#
# </div>

# %%
data.filter("Open >=3.0").show(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+-----+-----+-----+-----+---------+--------+
#       Date| Open| High|  Low|Close|Adj Close|  Volume|
# +----------+-----+-----+-----+-----+---------+--------+
# 2010-06-29|  3.8|  5.0|3.508|4.778|    4.778|93831500|
# 2010-06-30|5.158|6.084| 4.66|4.766|    4.766|85935500|
# 2010-07-01|  5.0|5.184|4.054|4.392|    4.392|41094000|
# +----------+-----+-----+-----+-----+---------+--------+
# only showing top 3 rows
#
# </div>

# %%
data.filter("Volume <= 41094000").select(['Open','Close']).show(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-----+
# Open|Close|
# +----+-----+
#  5.0|4.392|
#  4.6| 3.84|
#  4.0|3.222|
# +----+-----+
# only showing top 3 rows
#
# </div>

# %% [markdown]
# ### filtering the data by using the between condition

# %%
## fetch the data where the adjusted value is between 100.0 and 500.0

data.filter(data.High.between(4.0, 4.5)).show(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+-----+----+-----+-----+---------+--------+
#       Date| Open|High|  Low|Close|Adj Close|  Volume|
# +----------+-----+----+-----+-----+---------+--------+
# 2010-07-06|  4.0| 4.0|3.166|3.222|    3.222|34334500|
# 2010-07-14|3.588|4.03|3.552|3.968|    3.968|20976000|
# +----------+-----+----+-----+-----+---------+--------+
# only showing top 2 rows
#
# </div>

# %% [markdown]
# ### filtering the data by using the When condition

# %%
from pyspark.sql import functions as f
data.select('open', 'close', 
            f.when(data.High >= 4.0, 1).otherwise(0)
           ).show(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+-----+-----------------------------------------+
#  open|close|CASE WHEN (High &gt;= 4.0) THEN 1 ELSE 0 END|
# +-----+-----+-----------------------------------------+
#   3.8|4.778|                                        1|
# 5.158|4.766|                                        1|
# +-----+-----+-----------------------------------------+
# only showing top 2 rows
#
# </div>

# %% [markdown]
# ### filtering the data by using the like condition

# %%
data.select('Open', 
            data.Open.rlike('^[3]').alias('open with 3')
            ).distinct().show(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+-----------+
#  Open|open with 3|
# +-----+-----------+
# 5.158|      false|
#   3.8|       true|
# +-----+-----------+
# only showing top 2 rows
#
# </div>

# %% [markdown]
# ### Pyspark GroupBy

# %%
data.groupBy('Volume').avg().show(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------+---------+---------+---------+----------+--------------+-----------+
#   Volume|avg(Open)|avg(High)| avg(Low)|avg(Close)|avg(Adj Close)|avg(Volume)|
# +--------+---------+---------+---------+----------+--------------+-----------+
#  4624000|    4.932|    4.998|    4.854|     4.944|         4.944|  4624000.0|
#  3154500|    5.568|    5.678|    5.512|     5.582|         5.582|  3154500.0|
# 29435000|46.914001|46.976002|45.599998| 46.285999|     46.285999|   2.9435E7|
# +--------+---------+---------+---------+----------+--------------+-----------+
# only showing top 3 rows
#
# </div>
