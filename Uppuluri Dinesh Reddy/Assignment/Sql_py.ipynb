# %%
import pandas as pd
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### First table

# %%
# %sql
DROP TABLE Product
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
CREATE TABLE Product(
  product_name varchar(40),
  issue_date Double,
  price int,
  Brand varchar(40),
  country varchar(40),
  product_number int
);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
select * from product
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_name</th><th>issue_date</th><th>price</th><th>Brand</th><th>country</th><th>product_number</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
INSERT INTO product VALUES("Washing Machine", 1648770933000, 20000, "Samsung", "India", 1),
                          ("Refrigerator", 1648770999000, 35000, "   LG", "null", 2),
                          ("Air Cooler", 1648770948000, 45000, "    Voltas", "null", 3)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>3</td><td>3</td></tr></tbody></table></div>

# %%
# %sql
select * from product
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_name</th><th>issue_date</th><th>price</th><th>Brand</th><th>country</th><th>product_number</th></tr></thead><tbody><tr><td>Washing Machine</td><td>1.648770933E12</td><td>20000</td><td>Samsung</td><td>India</td><td>1</td></tr><tr><td>Air Cooler</td><td>1.648770948E12</td><td>45000</td><td>    Voltas</td><td>null</td><td>3</td></tr><tr><td>Refrigerator</td><td>1.648770999E12</td><td>35000</td><td>   LG</td><td>null</td><td>2</td></tr></tbody></table></div>

# %%
df = _sqldf.toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[134]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>product_name</th>
#       <th>issue_date</th>
#       <th>price</th>
#       <th>Brand</th>
#       <th>country</th>
#       <th>product_number</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Washing Machine</td>
#       <td>1.648771e+12</td>
#       <td>20000</td>
#       <td>Samsung</td>
#       <td>India</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Air Cooler</td>
#       <td>1.648771e+12</td>
#       <td>45000</td>
#       <td>Voltas</td>
#       <td>null</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Refrigerator</td>
#       <td>1.648771e+12</td>
#       <td>35000</td>
#       <td>LG</td>
#       <td>null</td>
#       <td>2</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
from datetime import datetime
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# <p>a)	Convert the Issue Date with the timestamp format.</p>

# %%
def timestamp_1(col):
    df[col] = df[col].apply(lambda x:  datetime.fromtimestamp(x/1000))
    return df[col]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
timestamp_1("issue_date")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[137]: 0   2022-03-31 23:55:33
# 1   2022-03-31 23:55:48
# 2   2022-03-31 23:56:39
# Name: issue_date, dtype: datetime64[ns]</div>

# %% [markdown]
# <p>b)	Convert timestamp to date type</p>

# %%
df['Date'] = pd.to_datetime(df['issue_date']).dt.date
df
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[138]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>product_name</th>
#       <th>issue_date</th>
#       <th>price</th>
#       <th>Brand</th>
#       <th>country</th>
#       <th>product_number</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Washing Machine</td>
#       <td>2022-03-31 23:55:33</td>
#       <td>20000</td>
#       <td>Samsung</td>
#       <td>India</td>
#       <td>1</td>
#       <td>2022-03-31</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Air Cooler</td>
#       <td>2022-03-31 23:55:48</td>
#       <td>45000</td>
#       <td>Voltas</td>
#       <td>null</td>
#       <td>3</td>
#       <td>2022-03-31</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Refrigerator</td>
#       <td>2022-03-31 23:56:39</td>
#       <td>35000</td>
#       <td>LG</td>
#       <td>null</td>
#       <td>2</td>
#       <td>2022-03-31</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# <p>d)	Replace null values with empty values in Country column</p>

# %%
def remove_null(col):
        df[col] = df[col].apply(lambda x: x.replace("null"," ") if "null" in x else x)
        return df[col]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
remove_null("country")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[140]: 0    India
# 1
# 2
# Name: country, dtype: object</div>

# %% [markdown]
# <p>c)	Remove the starting extra space in Brand column for LG and Voltas fields</p>

# %%
def remove_space(col):
    df[col] = df[col].apply(lambda x: x.strip())
    return df[col]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
remove_space("Brand")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[142]: 0    Samsung
# 1     Voltas
# 2         LG
# Name: Brand, dtype: object</div>

# %%
df
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[143]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>product_name</th>
#       <th>issue_date</th>
#       <th>price</th>
#       <th>Brand</th>
#       <th>country</th>
#       <th>product_number</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Washing Machine</td>
#       <td>2022-03-31 23:55:33</td>
#       <td>20000</td>
#       <td>Samsung</td>
#       <td>India</td>
#       <td>1</td>
#       <td>2022-03-31</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Air Cooler</td>
#       <td>2022-03-31 23:55:48</td>
#       <td>45000</td>
#       <td>Voltas</td>
#       <td></td>
#       <td>3</td>
#       <td>2022-03-31</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Refrigerator</td>
#       <td>2022-03-31 23:56:39</td>
#       <td>35000</td>
#       <td>LG</td>
#       <td></td>
#       <td>2</td>
#       <td>2022-03-31</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### Second table

# %%
# %sql
DROP TABLE transaction_data
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
CREATE TABLE transaction_data(
  SourceId int,
  TransactionNumber int,
  Language varchar(10),
  ModelNumber int,
  StartTime varchar(40),
  ProductNumber int 
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
select * from transaction_data
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>SourceId</th><th>TransactionNumber</th><th>Language</th><th>ModelNumber</th><th>StartTime</th><th>ProductNumber</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
INSERT INTO transaction_data VALUES (150711, 123456, "EN", 456789, "2021-12-27T08:20:29.842", 0001),
                                    (150439, 234567, "UK", 345678, "2021-12-27T08:21:14.645", 0002),
                                    (150647, 345678, "ES", 234567, "2021-12-27T08:22:42.445", 0003)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>3</td><td>3</td></tr></tbody></table></div>

# %%
# %sql
select * from transaction_data
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>SourceId</th><th>TransactionNumber</th><th>Language</th><th>ModelNumber</th><th>StartTime</th><th>ProductNumber</th></tr></thead><tbody><tr><td>150711</td><td>123456</td><td>EN</td><td>456789</td><td>2021-12-27T08:20:29.842</td><td>1</td></tr><tr><td>150439</td><td>234567</td><td>UK</td><td>345678</td><td>2021-12-27T08:21:14.645</td><td>2</td></tr><tr><td>150647</td><td>345678</td><td>ES</td><td>234567</td><td>2021-12-27T08:22:42.445</td><td>3</td></tr></tbody></table></div>

# %%
trns_df = _sqldf.toPandas()
trns_df
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[149]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>SourceId</th>
#       <th>TransactionNumber</th>
#       <th>Language</th>
#       <th>ModelNumber</th>
#       <th>StartTime</th>
#       <th>ProductNumber</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>150711</td>
#       <td>123456</td>
#       <td>EN</td>
#       <td>456789</td>
#       <td>2021-12-27T08:20:29.842</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>150439</td>
#       <td>234567</td>
#       <td>UK</td>
#       <td>345678</td>
#       <td>2021-12-27T08:21:14.645</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>150647</td>
#       <td>345678</td>
#       <td>ES</td>
#       <td>234567</td>
#       <td>2021-12-27T08:22:42.445</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
import re
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# <p>a)	Change the camel case columns to snake case <br>
# Example: SourceId: source_id, TransactionNumber: transaction_number
# </p>

# %%
column = trns_df.columns.to_list()
def split_on_uppercase():
    for i in column:
        column_split = re.findall("[a-zA-Z][^A-Z]*",i)
        underscore_split = "_".join(column_split).lower()
        trns_df.rename(columns= {i:underscore_split}, inplace=True)
    return trns_df
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
split_on_uppercase()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[152]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>source_id</th>
#       <th>transaction_number</th>
#       <th>language</th>
#       <th>model_number</th>
#       <th>start_time</th>
#       <th>product_number</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>150711</td>
#       <td>123456</td>
#       <td>EN</td>
#       <td>456789</td>
#       <td>2021-12-27T08:20:29.842</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>150439</td>
#       <td>234567</td>
#       <td>UK</td>
#       <td>345678</td>
#       <td>2021-12-27T08:21:14.645</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>150647</td>
#       <td>345678</td>
#       <td>ES</td>
#       <td>234567</td>
#       <td>2021-12-27T08:22:42.445</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# <p>b)	Add another column as start_time_ms and convert the values of StartTime to milliseconds.</p>

# %%
trns_df['start_time'] = pd.to_datetime(trns_df['start_time'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from datetime import datetime
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
trns_df['start_time']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[155]: 0   2021-12-27 08:20:29.842
# 1   2021-12-27 08:21:14.645
# 2   2021-12-27 08:22:42.445
# Name: start_time, dtype: datetime64[ns]</div>

# %% [markdown]
# <p>b)	Add another column as start_time_ms and convert the values of StartTime to milliseconds.</p>

# %%
def date_timestamp(col):
    for i in trns_df[col]:
        trns_df[col] = datetime.timestamp(i)
    return trns_df
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
date_timestamp("start_time")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[157]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>source_id</th>
#       <th>transaction_number</th>
#       <th>language</th>
#       <th>model_number</th>
#       <th>start_time</th>
#       <th>product_number</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>150711</td>
#       <td>123456</td>
#       <td>EN</td>
#       <td>456789</td>
#       <td>1.640593e+09</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>150439</td>
#       <td>234567</td>
#       <td>UK</td>
#       <td>345678</td>
#       <td>1.640593e+09</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>150647</td>
#       <td>345678</td>
#       <td>ES</td>
#       <td>234567</td>
#       <td>1.640593e+09</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# <p>3.	Combine both the tables based on the Product Number <br>
# •	    and get all the fields in return.<br>
# •	    And get the country as EN <br>
# </p>

# %%
df_final = pd.merge(trns_df, df, on='product_number').set_index("product_number")
df_final
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[158]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>source_id</th>
#       <th>transaction_number</th>
#       <th>language</th>
#       <th>model_number</th>
#       <th>start_time</th>
#       <th>product_name</th>
#       <th>issue_date</th>
#       <th>price</th>
#       <th>Brand</th>
#       <th>country</th>
#       <th>Date</th>
#     </tr>
#     <tr>
#       <th>product_number</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>150711</td>
#       <td>123456</td>
#       <td>EN</td>
#       <td>456789</td>
#       <td>1.640593e+09</td>
#       <td>Washing Machine</td>
#       <td>2022-03-31 23:55:33</td>
#       <td>20000</td>
#       <td>Samsung</td>
#       <td>India</td>
#       <td>2022-03-31</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>150439</td>
#       <td>234567</td>
#       <td>UK</td>
#       <td>345678</td>
#       <td>1.640593e+09</td>
#       <td>Refrigerator</td>
#       <td>2022-03-31 23:56:39</td>
#       <td>35000</td>
#       <td>LG</td>
#       <td></td>
#       <td>2022-03-31</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>150647</td>
#       <td>345678</td>
#       <td>ES</td>
#       <td>234567</td>
#       <td>1.640593e+09</td>
#       <td>Air Cooler</td>
#       <td>2022-03-31 23:55:48</td>
#       <td>45000</td>
#       <td>Voltas</td>
#       <td></td>
#       <td>2022-03-31</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df_final[df_final['language'] == "EN"]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[159]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>source_id</th>
#       <th>transaction_number</th>
#       <th>language</th>
#       <th>model_number</th>
#       <th>start_time</th>
#       <th>product_name</th>
#       <th>issue_date</th>
#       <th>price</th>
#       <th>Brand</th>
#       <th>country</th>
#       <th>Date</th>
#     </tr>
#     <tr>
#       <th>product_number</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>150711</td>
#       <td>123456</td>
#       <td>EN</td>
#       <td>456789</td>
#       <td>1.640593e+09</td>
#       <td>Washing Machine</td>
#       <td>2022-03-31 23:55:33</td>
#       <td>20000</td>
#       <td>Samsung</td>
#       <td>India</td>
#       <td>2022-03-31</td>
#     </tr>
#   </tbody>
# </table>
# </div>
